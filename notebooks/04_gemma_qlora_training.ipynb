# %% [markdown]
# # 04 — Gemma QLoRA training (GPU)
#
# ```bash
# python -m controlsift.training.train --smoke
# python -m controlsift.training.train
# ```
#
# Verify LoRA target modules against the loaded Gemma architecture before full runs.

# %%
print('Train on Kaggle/Colab; commit metrics and adapter metadata, not secrets.')

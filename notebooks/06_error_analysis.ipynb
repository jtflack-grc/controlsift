# %% [markdown]
# # 06 — Error analysis
#
# See `reports/ERROR_ANALYSIS.md` and `docs/data/failure_lab.json`.

# %%
import json
from pathlib import Path
lab = json.loads(Path('../docs/data/failure_lab.json').read_text(encoding='utf-8'))
print(len(lab['cases']), 'Failure Lab cases')

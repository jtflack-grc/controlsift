# %% [markdown]
# # 03 — Gemma baselines (GPU)
#
# Intended for Kaggle/Colab after `pip install -e ".[gpu]"`.
#
# ```bash
# python scripts/run_gemma_baseline.py --mode zero_shot --split validation --limit 8
# python scripts/run_gemma_baseline.py --mode few_shot --split validation --limit 8
# ```

# %%
print('Use scripts/run_gemma_baseline.py on a GPU runtime with HF access to google/gemma-3-1b-it')

# %% [markdown]
# # 02 — Traditional baseline
#
# Run `python scripts/run_tfidf_baseline.py` then inspect metrics.

# %%
import json
from pathlib import Path
p = Path('../results/tfidf/metrics_test.json')
print(json.dumps(json.loads(p.read_text(encoding='utf-8'))['metrics']['macro_f1'], indent=2) if p.exists() else 'Run baseline script first')

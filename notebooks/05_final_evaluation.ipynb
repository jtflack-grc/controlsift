# %% [markdown]
# # 05 — Final evaluation
#
# Only after protocol lock and Gate 3. Sync public results with `python scripts/run_evaluation.py`.

# %%
import json
from pathlib import Path
print(json.loads(Path('../docs/data/results.json').read_text(encoding='utf-8'))['status'])
